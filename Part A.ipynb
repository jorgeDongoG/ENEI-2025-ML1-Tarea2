# %%
from ucimlrepo import fetch_ucirepo
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Part A. Binary Logistic Regression from Scratch

# %% [markdown]
# Reading, preprocessing and cleaning data

# %%
heart_disease = fetch_ucirepo(id = 45)
X = heart_disease.data.features # features
Y = heart_disease.data.targets # heart disease diagnosis
Y['num'] = (Y['num'] != 0)*1
# Out:
# C:\Users\aula02\AppData\Local\Temp\ipykernel_9704\2008545978.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['num'] = (Y['num'] != 0)*1

# %%
display(X.head(5))
display(X.info())
display(X.describe())
display(heart_disease.variables)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
# dtypes: float64(3), int64(10)
# memory usage: 30.9 KB
# None
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal
# count  301.000000
# mean     4.734219
# std      1.939706
# min      3.000000
# 25%      3.000000
# 50%      3.000000
# 75%      7.000000
# max      7.000000
#         name     role         type demographic  \
# 0        age  Feature      Integer         Age
# 1        sex  Feature  Categorical         Sex
# 2         cp  Feature  Categorical        None
# 3   trestbps  Feature      Integer        None
# 4       chol  Feature      Integer        None
# 5        fbs  Feature  Categorical        None
# 6    restecg  Feature  Categorical        None
# 7    thalach  Feature      Integer        None
# 8      exang  Feature  Categorical        None
# 9    oldpeak  Feature      Integer        None
# 10     slope  Feature  Categorical        None
# 11        ca  Feature      Integer        None
# 12      thal  Feature  Categorical        None
# 13       num   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None  years             no
# 1                                                None   None             no
# 2                                                None   None             no
# 3   resting blood pressure (on admission to the ho...  mm Hg             no
# 4                                   serum cholestoral  mg/dl             no
# 5                     fasting blood sugar > 120 mg/dl   None             no
# 6                                                None   None             no
# 7                         maximum heart rate achieved   None             no
# 8                             exercise induced angina   None             no
# 9   ST depression induced by exercise relative to ...   None             no
# 10                                               None   None             no
# 11  number of major vessels (0-3) colored by flour...   None            yes
# 12                                               None   None            yes
# 13                         diagnosis of heart disease   None             no

# %%
X_cat = X[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal']]
X_num = X[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']]

# %% [markdown]
# Encode categorical features

# %%
enc = OneHotEncoder(drop='first', sparse_output=False)

# %%
X_enc = enc.fit_transform(X_cat)
column_names = enc.get_feature_names_out(X_cat.columns)
X_enc = pd.DataFrame(X_enc, columns=column_names, index=X_cat.index)

# %% [markdown]
# Standardize numeric features

# %%
for cat in X_num.columns:
    X_num[cat] = (X_num[cat] - min(X_num[cat])) / (max(X_num[cat]) - min(X_num[cat]))
# Out:
# C:\Users\aula02\AppData\Local\Temp\ipykernel_9704\141412892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_num[cat] = (X_num[cat] - min(X_num[cat])) / (max(X_num[cat]) - min(X_num[cat]))
# C:\Users\aula02\AppData\Local\Temp\ipykernel_9704\141412892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_num[cat] = (X_num[cat] - min(X_num[cat])) / (max(X_num[cat]) - min(X_num[cat]))
# C:\Users\aula02\AppData\Local\Temp\ipykernel_9704\141412892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_num[cat] = (X_num[cat] - min(X_num[cat])) / (max(X_num[cat]) - min(X_num[cat]))
# C:\Users\aula02\AppData\Local\Temp\ipykernel_9704\141412892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_num[cat] = (X_num[cat] - min(X_num[cat])) / (max(X_num[cat]) - min(X_num[cat]))

# %%
X_final = pd.concat([X_cat, X_num], axis=1)

# %% [markdown]
# The missings are so few that can be just deleted

# %%
pd.concat([X_final, Y], axis=1)
# Out:
#      sex  cp  fbs  restecg  exang  slope  thal       age  trestbps      chol  \
# 0      1   1    1        2      0      3   6.0  0.708333  0.481132  0.244292
# 1      1   4    0        2      1      2   3.0  0.791667  0.622642  0.365297
# 2      1   4    0        2      1      2   7.0  0.791667  0.245283  0.235160
# 3      1   3    0        0      0      3   3.0  0.166667  0.339623  0.283105
# 4      0   2    0        2      0      1   3.0  0.250000  0.339623  0.178082
# ..   ...  ..  ...      ...    ...    ...   ...       ...       ...       ...
# 298    1   1    0        0      0      2   7.0  0.333333  0.150943  0.315068
# 299    1   4    1        0      0      2   7.0  0.812500  0.471698  0.152968
# 300    1   4    0        0      1      2   7.0  0.583333  0.339623  0.011416
# 301    0   2    0        2      0      2   3.0  0.583333  0.339623  0.251142
# 302    1   3    0        0      0      1   3.0  0.187500  0.415094  0.111872
#
#       thalach   oldpeak        ca  num
# 0    0.603053  0.370968  0.000000    0
# 1    0.282443  0.241935  1.000000    1
# 2    0.442748  0.419355  0.666667    1
# 3    0.885496  0.564516  0.000000    0
# 4    0.770992  0.225806  0.000000    0
# ..        ...       ...       ...  ...
# 298  0.465649  0.193548  0.000000    1
# 299  0.534351  0.548387  0.666667    1
# 300  0.335878  0.193548  0.333333    1
# 301  0.786260  0.000000  0.333333    1
# 302  0.778626  0.000000       NaN    0
#
# [303 rows x 14 columns]

# %%
df = pd.concat([X_final, Y], axis=1)
df = df.dropna()

# %%
X_final = df[[c for c in df.columns if c!= 'num']]
Y_final = df[['num']]

# %% [markdown]
# Creating the optimization algorithm

# %%
def sigmoid(z):
    s = 1 / (1 + np.exp(-z))
    return s

def f(X,theta):
    f = sigmoid(X.dot(theta))
    return f

def log_likelihood(X,Y,theta):
    return (Y*np.log(f(X,theta) + 1e-6 ) + (1-Y)*np.log(1-f(X,theta) + 1e-6)).mean()

def loglik_gradient(theta, X, Y):
    return X.T @ (f(X, theta)-Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final.to_numpy(), Y_final['num'], test_size=0.3, random_state=42)

# %%
threshold = 1e-5
step_size = 5e-4

theta, theta_prev = np.zeros((13,)) , np.ones((13,))
opt_pts = [theta]
opt_grads = []
iter = 0

max_iter = 2000000

I0 = []
LL0 = []

while np.linalg.norm(theta - theta_prev) > threshold:
    LL = log_likelihood(X_train, y_train, theta)
    if iter % 500 == 0:
        print('Iteration %d. Log-likelihood: %.6f' % (iter, LL))
    theta_prev = theta
    gradient = loglik_gradient(theta, X_train, y_train)
    theta = theta_prev - step_size * gradient
    opt_pts += [theta]
    opt_grads += [gradient]
    I0.append(iter)
    LL0.append(LL)
    iter += 1
    if iter == max_iter:
        print('Max iter reached')
        break

print('Iteration %d. Log-likelihood: %.6f' % (iter, log_likelihood(X_train, y_train, theta)))
# Out:
# Iteration 0. Log-likelihood: -0.693145
# Iteration 500. Log-likelihood: -0.449126
# Iteration 1000. Log-likelihood: -0.418681
# Iteration 1500. Log-likelihood: -0.407213
# Iteration 2000. Log-likelihood: -0.401189
# Iteration 2500. Log-likelihood: -0.397381
# Iteration 3000. Log-likelihood: -0.394704
# Iteration 3500. Log-likelihood: -0.392702
# Iteration 4000. Log-likelihood: -0.391149
# Iteration 4500. Log-likelihood: -0.389916
# Iteration 5000. Log-likelihood: -0.388920
# Iteration 5500. Log-likelihood: -0.388107
# Iteration 6000. Log-likelihood: -0.387435
# Iteration 6500. Log-likelihood: -0.386876
# Iteration 7000. Log-likelihood: -0.386407
# Iteration 7500. Log-likelihood: -0.386011
# Iteration 8000. Log-likelihood: -0.385675
# Iteration 8500. Log-likelihood: -0.385389
# Iteration 9000. Log-likelihood: -0.385143
# Iteration 9500. Log-likelihood: -0.384932
# Iteration 10000. Log-likelihood: -0.384749
# Iteration 10500. Log-likelihood: -0.384591
# Iteration 11000. Log-likelihood: -0.384454
# Iteration 11500. Log-likelihood: -0.384335
# Iteration 12000. Log-likelihood: -0.384230
# Iteration 12500. Log-likelihood: -0.384139
# Iteration 13000. Log-likelihood: -0.384059
# Iteration 13500. Log-likelihood: -0.383989
# Iteration 14000. Log-likelihood: -0.383928
# Iteration 14500. Log-likelihood: -0.383874
# Iteration 15000. Log-likelihood: -0.383827
# Iteration 15500. Log-likelihood: -0.383785
# Iteration 16000. Log-likelihood: -0.383748
# Iteration 16500. Log-likelihood: -0.383715
# Iteration 17000. Log-likelihood: -0.383687
# Iteration 17500. Log-likelihood: -0.383661
# Iteration 18000. Log-likelihood: -0.383639
# Iteration 18500. Log-likelihood: -0.383619
# Iteration 19000. Log-likelihood: -0.383602
# Iteration 19500. Log-likelihood: -0.383586
# Iteration 20000. Log-likelihood: -0.383572
# Iteration 20500. Log-likelihood: -0.383560
# Iteration 21000. Log-likelihood: -0.383550
# Iteration 21500. Log-likelihood: -0.383540
# Iteration 22000. Log-likelihood: -0.383532
# Iteration 22500. Log-likelihood: -0.383524
# Iteration 23000. Log-likelihood: -0.383518
# Iteration 23500. Log-likelihood: -0.383512
# Iteration 24000. Log-likelihood: -0.383507
# Iteration 24500. Log-likelihood: -0.383502
# Iteration 25000. Log-likelihood: -0.383498
# Iteration 25500. Log-likelihood: -0.383494
# Iteration 26000. Log-likelihood: -0.383491
# Iteration 26500. Log-likelihood: -0.383488
# Iteration 27000. Log-likelihood: -0.383486
# Iteration 27500. Log-likelihood: -0.383484
# Iteration 28000. Log-likelihood: -0.383482
# Iteration 28500. Log-likelihood: -0.383480
# Iteration 29000. Log-likelihood: -0.383478
# Iteration 29500. Log-likelihood: -0.383477
# Iteration 30000. Log-likelihood: -0.383476
# Iteration 30500. Log-likelihood: -0.383475
# Iteration 31000. Log-likelihood: -0.383474
# Iteration 31500. Log-likelihood: -0.383473
# Iteration 32000. Log-likelihood: -0.383472
# Iteration 32500. Log-likelihood: -0.383471
# Iteration 33000. Log-likelihood: -0.383471
# Iteration 33500. Log-likelihood: -0.383470
# Iteration 33658. Log-likelihood: -0.383470

# %%
y_test_prob = f(X_test, theta)
y_test_pred = (y_test_prob >= 0.5) * 1

# %%
threshold = 1e-5
step_size = 8e-5

theta, theta_prev = np.zeros((13,)) , np.ones((13,))
opt_pts = [theta]
opt_grads = []
iter = 0

max_iter = 2000000

I1 = []
LL1 = []

while np.linalg.norm(theta - theta_prev) > threshold:
    LL = log_likelihood(X_train, y_train, theta)
    if iter % 500 == 0:
        print('Iteration %d. Log-likelihood: %.6f' % (iter, LL))
    theta_prev = theta
    gradient = loglik_gradient(theta, X_train, y_train)
    theta = theta_prev - step_size * gradient
    opt_pts += [theta]
    opt_grads += [gradient]
    I1.append(iter)
    LL1.append(LL)
    iter += 1
    if iter == max_iter:
        print('Max iter reached')
        break

print('Iteration %d. Log-likelihood: %.6f' % (iter, log_likelihood(X_train, y_train, theta)))
# Out:
# Iteration 0. Log-likelihood: -0.693145
# Iteration 500. Log-likelihood: -0.573220
# Iteration 1000. Log-likelihood: -0.525589
# Iteration 1500. Log-likelihood: -0.496130
# Iteration 2000. Log-likelihood: -0.476284
# Iteration 2500. Log-likelihood: -0.462071
# Iteration 3000. Log-likelihood: -0.451426
# Iteration 3500. Log-likelihood: -0.443180
# Iteration 4000. Log-likelihood: -0.436624
# Iteration 4500. Log-likelihood: -0.431302
# Iteration 5000. Log-likelihood: -0.426906
# Iteration 5500. Log-likelihood: -0.423221
# Iteration 6000. Log-likelihood: -0.420092
# Iteration 6500. Log-likelihood: -0.417406
# Iteration 7000. Log-likelihood: -0.415076
# Iteration 7500. Log-likelihood: -0.413037
# Iteration 8000. Log-likelihood: -0.411237
# Iteration 8500. Log-likelihood: -0.409637
# Iteration 9000. Log-likelihood: -0.408203
# Iteration 9500. Log-likelihood: -0.406912
# Iteration 10000. Log-likelihood: -0.405741
# Iteration 10500. Log-likelihood: -0.404673
# Iteration 11000. Log-likelihood: -0.403696
# Iteration 11500. Log-likelihood: -0.402796
# Iteration 12000. Log-likelihood: -0.401965
# Iteration 12500. Log-likelihood: -0.401194
# Iteration 13000. Log-likelihood: -0.400477
# Iteration 13500. Log-likelihood: -0.399807
# Iteration 14000. Log-likelihood: -0.399179
# Iteration 14500. Log-likelihood: -0.398590
# Iteration 15000. Log-likelihood: -0.398035
# Iteration 15500. Log-likelihood: -0.397511
# Iteration 16000. Log-likelihood: -0.397016
# Iteration 16500. Log-likelihood: -0.396547
# Iteration 17000. Log-likelihood: -0.396102
# Iteration 17500. Log-likelihood: -0.395679
# Iteration 18000. Log-likelihood: -0.395276
# Iteration 18500. Log-likelihood: -0.394892
# Iteration 19000. Log-likelihood: -0.394525
# Iteration 19500. Log-likelihood: -0.394175
# Iteration 20000. Log-likelihood: -0.393840
# Iteration 20500. Log-likelihood: -0.393520
# Iteration 21000. Log-likelihood: -0.393212
# Iteration 21500. Log-likelihood: -0.392917
# Iteration 22000. Log-likelihood: -0.392634
# Iteration 22500. Log-likelihood: -0.392363
# Iteration 23000. Log-likelihood: -0.392101
# Iteration 23500. Log-likelihood: -0.391850
# Iteration 24000. Log-likelihood: -0.391608
# Iteration 24500. Log-likelihood: -0.391375
# Iteration 25000. Log-likelihood: -0.391151
# Iteration 25500. Log-likelihood: -0.390935
# Iteration 26000. Log-likelihood: -0.390726
# Iteration 26500. Log-likelihood: -0.390525
# Iteration 27000. Log-likelihood: -0.390330
# Iteration 27500. Log-likelihood: -0.390143
# Iteration 28000. Log-likelihood: -0.389962
# Iteration 28500. Log-likelihood: -0.389787
# Iteration 29000. Log-likelihood: -0.389617
# Iteration 29500. Log-likelihood: -0.389454
# Iteration 30000. Log-likelihood: -0.389295
# Iteration 30500. Log-likelihood: -0.389142
# Iteration 31000. Log-likelihood: -0.388994
# Iteration 31500. Log-likelihood: -0.388850
# Iteration 32000. Log-likelihood: -0.388711
# Iteration 32500. Log-likelihood: -0.388577
# Iteration 33000. Log-likelihood: -0.388446
# Iteration 33500. Log-likelihood: -0.388320
# Iteration 34000. Log-likelihood: -0.388197
# Iteration 34500. Log-likelihood: -0.388078
# Iteration 35000. Log-likelihood: -0.387963
# Iteration 35500. Log-likelihood: -0.387851
# Iteration 36000. Log-likelihood: -0.387743
# Iteration 36500. Log-likelihood: -0.387637
# Iteration 37000. Log-likelihood: -0.387535
# Iteration 37500. Log-likelihood: -0.387436
# Iteration 38000. Log-likelihood: -0.387339
# Iteration 38500. Log-likelihood: -0.387246
# Iteration 39000. Log-likelihood: -0.387155
# Iteration 39500. Log-likelihood: -0.387066
# Iteration 40000. Log-likelihood: -0.386981
# Iteration 40500. Log-likelihood: -0.386897
# Iteration 41000. Log-likelihood: -0.386816
# Iteration 41500. Log-likelihood: -0.386737
# Iteration 42000. Log-likelihood: -0.386660
# Iteration 42500. Log-likelihood: -0.386586
# Iteration 43000. Log-likelihood: -0.386513
# Iteration 43500. Log-likelihood: -0.386442
# Iteration 44000. Log-likelihood: -0.386373
# Iteration 44500. Log-likelihood: -0.386306
# Iteration 45000. Log-likelihood: -0.386241
# Iteration 45500. Log-likelihood: -0.386178
# Iteration 46000. Log-likelihood: -0.386116
# Iteration 46500. Log-likelihood: -0.386056
# Iteration 47000. Log-likelihood: -0.385997
# Iteration 47500. Log-likelihood: -0.385940
# Iteration 48000. Log-likelihood: -0.385885
# Iteration 48500. Log-likelihood: -0.385830
# Iteration 49000. Log-likelihood: -0.385778
# Iteration 49500. Log-likelihood: -0.385726
# Iteration 50000. Log-likelihood: -0.385676
# Iteration 50500. Log-likelihood: -0.385627
# Iteration 51000. Log-likelihood: -0.385579
# Iteration 51500. Log-likelihood: -0.385533
# Iteration 52000. Log-likelihood: -0.385487
# Iteration 52500. Log-likelihood: -0.385443
# Iteration 53000. Log-likelihood: -0.385400
# Iteration 53500. Log-likelihood: -0.385358
# Iteration 54000. Log-likelihood: -0.385317
# Iteration 54500. Log-likelihood: -0.385276
# Iteration 55000. Log-likelihood: -0.385237
# Iteration 55500. Log-likelihood: -0.385199
# Iteration 56000. Log-likelihood: -0.385162
# Iteration 56500. Log-likelihood: -0.385125
# Iteration 57000. Log-likelihood: -0.385090
# Iteration 57500. Log-likelihood: -0.385055
# Iteration 58000. Log-likelihood: -0.385021
# Iteration 58500. Log-likelihood: -0.384988
# Iteration 59000. Log-likelihood: -0.384956
# Iteration 59500. Log-likelihood: -0.384924
# Iteration 60000. Log-likelihood: -0.384894
# Iteration 60500. Log-likelihood: -0.384863
# Iteration 61000. Log-likelihood: -0.384834
# Iteration 61500. Log-likelihood: -0.384805
# Iteration 62000. Log-likelihood: -0.384777
# Iteration 62500. Log-likelihood: -0.384750
# Iteration 63000. Log-likelihood: -0.384723
# Iteration 63500. Log-likelihood: -0.384697
# Iteration 64000. Log-likelihood: -0.384671
# Iteration 64500. Log-likelihood: -0.384646
# Iteration 65000. Log-likelihood: -0.384621
# Iteration 65500. Log-likelihood: -0.384598
# Iteration 66000. Log-likelihood: -0.384574
# Iteration 66500. Log-likelihood: -0.384551
# Iteration 67000. Log-likelihood: -0.384529
# Iteration 67500. Log-likelihood: -0.384507
# Iteration 68000. Log-likelihood: -0.384486
# Iteration 68500. Log-likelihood: -0.384465
# Iteration 69000. Log-likelihood: -0.384444
# Iteration 69500. Log-likelihood: -0.384424
# Iteration 70000. Log-likelihood: -0.384405
# Iteration 70500. Log-likelihood: -0.384385
# Iteration 71000. Log-likelihood: -0.384367
# Iteration 71500. Log-likelihood: -0.384348
# Iteration 72000. Log-likelihood: -0.384330
# Iteration 72500. Log-likelihood: -0.384313
# Iteration 73000. Log-likelihood: -0.384296
# Iteration 73500. Log-likelihood: -0.384279
# Iteration 74000. Log-likelihood: -0.384262
# Iteration 74500. Log-likelihood: -0.384246
# Iteration 75000. Log-likelihood: -0.384231
# Iteration 75500. Log-likelihood: -0.384215
# Iteration 76000. Log-likelihood: -0.384200
# Iteration 76500. Log-likelihood: -0.384185
# Iteration 77000. Log-likelihood: -0.384171
# Iteration 77500. Log-likelihood: -0.384157
# Iteration 78000. Log-likelihood: -0.384143
# Iteration 78500. Log-likelihood: -0.384129
# Iteration 79000. Log-likelihood: -0.384116
# Iteration 79500. Log-likelihood: -0.384103
# Iteration 80000. Log-likelihood: -0.384090
# Iteration 80500. Log-likelihood: -0.384078
# Iteration 81000. Log-likelihood: -0.384066
# Iteration 81500. Log-likelihood: -0.384054
# Iteration 82000. Log-likelihood: -0.384042
# Iteration 82500. Log-likelihood: -0.384030
# Iteration 83000. Log-likelihood: -0.384019
# Iteration 83500. Log-likelihood: -0.384008
# Iteration 84000. Log-likelihood: -0.383998
# Iteration 84500. Log-likelihood: -0.383987
# Iteration 85000. Log-likelihood: -0.383977
# Iteration 85500. Log-likelihood: -0.383967
# Iteration 86000. Log-likelihood: -0.383957
# Iteration 86500. Log-likelihood: -0.383947
# Iteration 87000. Log-likelihood: -0.383937
# Iteration 87500. Log-likelihood: -0.383928
# Iteration 88000. Log-likelihood: -0.383919
# Iteration 88500. Log-likelihood: -0.383910
# Iteration 89000. Log-likelihood: -0.383901
# Iteration 89500. Log-likelihood: -0.383893
# Iteration 90000. Log-likelihood: -0.383884
# Iteration 90500. Log-likelihood: -0.383876
# Iteration 91000. Log-likelihood: -0.383868
# Iteration 91500. Log-likelihood: -0.383860
# Iteration 92000. Log-likelihood: -0.383852
# Iteration 92500. Log-likelihood: -0.383845
# Iteration 93000. Log-likelihood: -0.383837
# Iteration 93500. Log-likelihood: -0.383830
# Iteration 94000. Log-likelihood: -0.383823
# Iteration 94500. Log-likelihood: -0.383816
# Iteration 95000. Log-likelihood: -0.383809
# Iteration 95500. Log-likelihood: -0.383803
# Iteration 96000. Log-likelihood: -0.383796
# Iteration 96500. Log-likelihood: -0.383790
# Iteration 97000. Log-likelihood: -0.383783
# Iteration 97500. Log-likelihood: -0.383777
# Iteration 98000. Log-likelihood: -0.383771
# Iteration 98500. Log-likelihood: -0.383765
# Iteration 99000. Log-likelihood: -0.383759
# Iteration 99500. Log-likelihood: -0.383753
# Iteration 100000. Log-likelihood: -0.383748
# Iteration 100500. Log-likelihood: -0.383742
# Iteration 101000. Log-likelihood: -0.383737
# Iteration 101500. Log-likelihood: -0.383732
# Iteration 102000. Log-likelihood: -0.383727
# Iteration 102500. Log-likelihood: -0.383722
# Iteration 103000. Log-likelihood: -0.383717
# Iteration 103500. Log-likelihood: -0.383712
# Iteration 104000. Log-likelihood: -0.383707
# Iteration 104500. Log-likelihood: -0.383702
# Iteration 105000. Log-likelihood: -0.383698
# Iteration 105500. Log-likelihood: -0.383693
# Iteration 106000. Log-likelihood: -0.383689
# Iteration 106500. Log-likelihood: -0.383685
# Iteration 107000. Log-likelihood: -0.383680
# Iteration 107500. Log-likelihood: -0.383676
# Iteration 108000. Log-likelihood: -0.383672
# Iteration 108500. Log-likelihood: -0.383668
# Iteration 109000. Log-likelihood: -0.383664
# Iteration 109500. Log-likelihood: -0.383660
# Iteration 110000. Log-likelihood: -0.383657
# Iteration 110500. Log-likelihood: -0.383653
# Iteration 111000. Log-likelihood: -0.383649
# Iteration 111500. Log-likelihood: -0.383646
# Iteration 112000. Log-likelihood: -0.383642
# Iteration 112500. Log-likelihood: -0.383639
# Iteration 113000. Log-likelihood: -0.383636
# Iteration 113500. Log-likelihood: -0.383632
# Iteration 114000. Log-likelihood: -0.383629
# Iteration 114500. Log-likelihood: -0.383626
# Iteration 115000. Log-likelihood: -0.383623
# Iteration 115249. Log-likelihood: -0.383621

# %%
plt.figure(figsize=(10, 6))
plt.plot(I0, LL0, label='lr=5e-4', color='blue', linewidth=2)
plt.plot(I1, LL1, label='lr=8e-5', color='red', linewidth=2)
plt.axvline(x=33658, color='blue', linestyle='--', linewidth=1, label=f'Convergence reached')
plt.axvline(x=115249, color='red', linestyle='--', linewidth=1, label=f'Convergence reached')
plt.title('Convergence plot')
plt.xlabel('Iter')
plt.ylabel('Log-likelihood')
plt.legend()
plt.grid(True)
plt.show()

# %%
lr = LogisticRegression(fit_intercept=True, random_state=1234)
lr.fit(X_train, y_train)
y_test_pred_sk = lr.predict(X_test)

# %% [markdown]
# Evaluation metrics

# %%
def find_conf_matrix_values(y_true,y_pred):
  TP = sum((y_true == 1) & (y_pred == 1))
  FN = sum((y_true == 0) & (y_pred == 1))
  FP = sum((y_true == 1) & (y_pred == 0))
  TN = sum((y_true == 0) & (y_pred == 0))
  return TP,FN,FP,TN

def my_accuracy_score(y_true, y_pred):
  TP,FN,FP,TN = find_conf_matrix_values(y_true,y_pred)
  return (TP + TN)/(TP + FN + FP + TN)

def my_precision_score(y_true, y_pred):
  TP,FN,FP,TN = find_conf_matrix_values(y_true,y_pred)
  return TP / (TP + FP)

def my_recall_score(y_true, y_pred):
  TP,FN,FP,TN = find_conf_matrix_values(y_true,y_pred)
  return TP / (TP + FN)

def my_f1_score(y_true, y_pred):
  recall = my_recall_score(y_true,y_pred)
  precision = my_precision_score(y_true,y_pred)
  return 2 * (precision * recall) / (precision + recall)

# %%
print('Results with Gradient Descent:\n')
print('Accuracy: %.6f' % (my_accuracy_score(y_test,y_test_pred)))
print('Precision: %.6f' % (my_precision_score(y_test,y_test_pred)))
print('Recall: %.6f' % my_recall_score(y_test,y_test_pred))
print('F1-Score: %.6f' % my_f1_score(y_test,y_test_pred))
# Out:
# Results with Gradient Descent:
#
# Accuracy: 0.866667
# Precision: 0.829268
# Recall: 0.871795
# F1-Score: 0.850000

# %%
print('Results with Sk-Learn:\n')
print('Accuracy: %.6f' % (my_accuracy_score(y_test,y_test_pred_sk)))
print('Precision: %.6f' % (my_precision_score(y_test,y_test_pred_sk)))
print('Recall: %.6f' % my_recall_score(y_test,y_test_pred_sk))
print('F1-Score: %.6f' % my_f1_score(y_test,y_test_pred_sk))
# Out:
# Results with Sk-Learn:
#
# Accuracy: 0.888889
# Precision: 0.853659
# Recall: 0.897436
# F1-Score: 0.875000

# %% [markdown]
# Despite the more time of computing, the results are better with sk-learn algorithm. This difference probably is result of the use of a better optimization strategy.
